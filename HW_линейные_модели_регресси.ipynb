# %% [markdown]
# <a href="https://colab.research.google.com/github/FilatovArtem/MTS_ML-Course/blob/main/HW_%D0%BB%D0%B8%D0%BD%D0%B5%D0%B8%CC%86%D0%BD%D1%8B%D0%B5_%D0%BC%D0%BE%D0%B4%D0%B5%D0%BB%D0%B8_%D1%80%D0%B5%D0%B3%D1%80%D0%B5%D1%81%D1%81%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание по регрессии

# %% [markdown]
# В разделе "4.3. Выбросы и модификация таргета" семинара мы с вами рассматривали датасет diabetes и пробовали популярные приемы для того чтобы лучше прогнозировать высокие значения (y > 270)

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
x_full, y_full = load_diabetes(return_X_y=True)
n_samples, n_features = x_full.shape

# %% [markdown]
# Напомним какой получался MAPE на наблюдениях с большими значениями y:
# *   MAPE без логарифмирования 0.24,
# *   после логарифмирования 0.26,
# *   после преобразования Бокса-Кокса 0.25
#
# С MSE картина обстояла еще более драматично
# *   без логарифмирования 5928.76
# *   после логарифмирования 7614.72
# *   после преобразования Бокса-Кокса 7028.17

# %% [markdown]
# **! Важно! На семинаре мы и обучались и измеряли качество на всей выборке. Здесь сначала поступим так же**

# %% [markdown]
# Что же делать в таком случае?
# Выходов не менее двух:
#
#
# 1. Использовать другую метрику чтобы оценивать результаты под другим углом -- это не изменит предсказания модели, но может оказаться, что модель и так уже приемлемо работает (MRAE, MDAPE, MASE, eB)
# 2. Использовать другую функцию потерь -- так, чтобы минимизировать ошибку в области больших значениях таргета. Здесь частный случай -- взвесить наблюдения пропорционально таргету

# %% [markdown]
# Давайте совместим оба пункта и в нашем SGD-классе будем оптимизировать сразу MAPE !

# %%
rng = np.random.default_rng(seed=121)
class sgd_lecture_linear:
  def __init__(self, rng, MAX_ITER = 100_000):
    self.MAX_ITER = MAX_ITER
    self.w = None
    self.w0 = rng.normal()
    self.loss = None
    return

  def _f(self, x):
    assert len(x) == len(self.w)
    return np.dot(self.w, x) + self.w0

  def _loss_mse(self, x, y):
    return (y - self._f(x)) ** 2

  def _der_loss(self, x, y):
    if self.loss == 'MSE':
      return -(y - self._f(x)) * x

  def fit(self, X_train, y_train, loss = 'MSE'):
    self.loss = loss
    self.w = rng.normal(size=X_train.shape[1])
    step = 0.01
    for k in range(self.MAX_ITER):
      rand_index = rng.integers(0, X_train.shape[0] - 1)
      x = np.array(X_train)[rand_index]
      y = np.array(y_train)[rand_index]
      if k % 10000 == 0:
         step = step / 2
      self.partial_fit(x, y, step)

  def partial_fit(self, x, y, step = 0.01):
    loss = self.loss
    if not self.w.any():
      self.w = rng.normal(len(x))
    dl = self._der_loss(x, y)
    self.w -= step * dl
    if self.loss == 'MSE':
      self.w0 -= - step * (y - self._f(x))

  def predict_proba(self, x):
    x = np.array(x)
    preds = []
    pred_fuction = None

    if self.loss in ['MSE']:
      pred_fuction = self._f
    for x_curr in x:
      preds.append(pred_fuction(x_curr))
    return preds

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error as mape

# %%
sgd = sgd_lecture_linear(rng)
sgd.fit(x_full, y_full)
print(f'{mape(y_full, sgd.predict_proba(x_full)):.2f}')
# Out:
# 0.50

# %% [markdown]
# Давайте посмотрим на MAPE

# %% [markdown]
# $$
# MAPE\_loss = \sum_i{\frac{|y_i - a_i|}{|y_i|}}
# $$

# %% [markdown]
# от MAE он отличается лишь весами, обратно пропорциональными таргету
#
# $$
# MAE\_loss = \sum_i{|y_i - a_i|}
# $$

# %% [markdown]
# давайте обучим взвешенный MSE

# %%
class sgd_lecture_linear:
  def __init__(self, rng, MAX_ITER = 50_000, sample_weights = None):
    self.MAX_ITER = MAX_ITER
    self.w = None
    self.w0 = rng.normal()
    self.loss = None
    self.epsilon = 1e-10
    return

  def _f(self, x):
    assert len(x) == len(self.w)
    return np.dot(self.w, x) + self.w0

  def _loss_mse(self, x, y):
    return (y - self._f(x)) ** 2

  def _der_loss(self, x, y, weight = 1):
      return -(y - self._f(x)) * x * weight

  def fit(self, X_train, y_train, loss = 'MSE', weights = None):
    self.loss = loss
    self.w = rng.normal(size=X_train.shape[1])
    step = 0.01
    if loss == 'MSE':
      for k in range(self.MAX_ITER):
        rand_index = rng.integers(0, X_train.shape[0] - 1)
        x = np.array(X_train)[rand_index]
        y = np.array(y_train)[rand_index]
        if k % 10000 == 0:
          step = step / 2
        self.partial_fit(x, y, step)
    elif loss == 'MSE_weighted':
      for k in range(self.MAX_ITER):
        rand_index = rng.integers(0, X_train.shape[0] - 1)
        x = np.array(X_train)[rand_index]
        y = np.array(y_train)[rand_index]
        weight = np.array(weights)[rand_index]
        if k % 10000 == 0:
          step = step / 2
        self.partial_fit(x, y, step, weight = weight)

  def partial_fit(self, x, y, step = 0.01, weight = 1):
    loss = self.loss
    if not self.w.any():
      self.w = rng.normal(len(x))
    dl = self._der_loss(x, y, weight = weight)
    self.w -= step * dl
    if self.loss == 'MSE':
      self.w0 -= - step * (y - self._f(x))
    if self.loss == 'MSE_weighted':
      self.w0 -= - step * (y - self._f(x)) * weight

  def predict_proba(self, x):
    x = np.array(x)
    preds = []
    pred_fuction = None

    if self.loss in ['MSE', 'MSE_weighted']:
      pred_fuction = self._f
    for x_curr in x:
      preds.append(pred_fuction(x_curr))
    return preds

# %%
sgd_mape = sgd_lecture_linear(rng)
weights =  (y_full - min(y_full)) / (max(y_full) - min(y_full)) + 0.1
weights = 1 / weights
sgd_mape.fit(x_full, y_full, loss = 'MSE_weighted', weights = weights)
print(f'{mape(y_full, sgd_mape.predict_proba(x_full)):.2f}')
# Out:
# 0.38

# %% [markdown]
# Ого! MAPE сильно упал! это здорово!

# %% [markdown]
# Давайте проверим что и в честном train-test split эффект сохранится

# %%
df = pd.DataFrame(x_full)
df['target'] = y_full
test_size = 0.3
random_state = 43
x_train, x_test, y_train, y_test = train_test_split(df.drop(['target'], axis = 1), df['target'], test_size=test_size, random_state=random_state)

# %%
sgd = sgd_lecture_linear(rng)
sgd.fit(x_train, y_train)
print(f'{mape(y_test, sgd.predict_proba(x_test)):.2f}', ' -- MAPE на тесте при обучении с обычным MSE')
sgd_mse_w = sgd_lecture_linear(rng)
weights =  (y_train - min(y_train)) / (max(y_train) - min(y_train)) + 0.03 # чтобы не делить на ноль
weights = 1 / weights
sgd_mse_w.fit(x_train, y_train, loss = 'MSE_weighted', weights = weights)
print(f'{mape(y_test, sgd_mse_w.predict_proba(x_test)):.2f}', ' -- MAPE на тесте при обучении на weighted MSE')
# Out:
# 0.50  -- MAPE на тесте при обучении с обычным MSE
# 0.35  -- MAPE на тесте при обучении на weighted MSE

# %% [markdown]
# Давайте померяем как стали прогнозироваться объекты с большими значениями таргета

# %%
df_test = pd.DataFrame(y_test, columns = ['target'])
df_test['pred_MSE'] = sgd.predict_proba(x_test)
df_test['pred_MSE_weighted'] = sgd_mse_w.predict_proba(x_test)
print(mape(df_test[df_test['target'] > 270]['target'], df_test[df_test['target'] > 270]['pred_MSE']), ' -- MAPE на тесте при обучении с обычным MSE на больших таргетах (>270)')
print(mape(df_test[df_test['target'] > 270]['target'], df_test[df_test['target'] > 270]['pred_MSE_weighted']), ' -- MAPE на тесте при обучении с weighted MSE на больших таргетах (>270)')
# Out:
# 0.37244520573827306  -- MAPE на тесте при обучении с обычным MSE на больших таргетах (>270)
# 0.4487208396445101  -- MAPE на тесте при обучении с weighted MSE на больших таргетах (>270)

# %% [markdown]
# Стало даже хуже!
# Давайте попробуем поменять веса у таких объектов

# %%
sgd = sgd_lecture_linear(rng)
sgd.fit(x_train, y_train)
print(f'{mape(y_test, sgd.predict_proba(x_test)):.2f}', ' -- MAPE на тесте при обучении с обычным MSE')
sgd_mse_w = sgd_lecture_linear(rng)
weights =  (y_train - min(y_train)) / (max(y_train) - min(y_train)) + 0.03 # чтобы не делить на ноль
weights = 1 / weights
for idx, y in zip(weights.index, y_train):
  if y > 270:
    weights[idx] = weights[idx] * 10

sgd_mse_w.fit(x_train, y_train, loss = 'MSE_weighted', weights = weights)
print(f'{mape(y_test, sgd_mse_w.predict_proba(x_test)):.2f}', ' -- MAPE на тесте при обучении на weighted MSE')

df_test = pd.DataFrame(y_test, columns = ['target'])
df_test['pred_MSE'] = sgd.predict_proba(x_test)
df_test['pred_MSE_weighted'] = sgd_mse_w.predict_proba(x_test)
mape_ordinary = mape(df_test[df_test['target'] > 270]['target'], df_test[df_test['target'] > 270]['pred_MSE'])
mape_weighted_mse = mape(df_test[df_test['target'] > 270]['target'], df_test[df_test['target'] > 270]['pred_MSE_weighted'])
print(f'{mape_ordinary:.2f}', ' -- MAPE на тесте (только на больших таргетах) при обучении с обычным MSE на больших таргетах (>270)')
print(f'{mape_weighted_mse:.2f}', ' -- MAPE на тесте (только на больших таргетах) при обучении с weighted MSE на больших таргетах (>270)')
# Out:
# 0.50  -- MAPE на тесте при обучении с обычным MSE
# 0.38  -- MAPE на тесте при обучении на weighted MSE
# 0.37  -- MAPE на тесте (только на больших таргетах) при обучении с обычным MSE на больших таргетах (>270)
# 0.22  -- MAPE на тесте (только на больших таргетах) при обучении с weighted MSE на больших таргетах (>270)

# %% [markdown]
# **Кажется, ошибка на больших значениях существенно снизилась!**
# Давайте нарисуем это

# %%
import plotly.express as px
import plotly.graph_objs as go

df = pd.DataFrame(dict(
    series=np.concatenate((["Таргет"] * len(y_test), ["Предсказание через оптимизацию MSE"] * len(y_test))),
    data=np.concatenate((y_test, df_test['pred_MSE']))
))


fig = px.histogram(df, x="data", color="series", barmode="overlay")
fig.update_layout(
                  title="Распределение таргетов и предиктов"
                  , xaxis_title="Таргеты"
                  , yaxis_title="Число"
                  , margin=dict(l=0, r=0, t=50, b=0)
                  , height=600
                  , width=900
                  , font_family="Arial"
                  , font_color="black"
                  , font_size = 20
                  , title_font_family="Times New Roman"
                  , title_font_size = 20
                  , title_font_color="black"
                  , separators=", .*"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cc5d57e1-9420-4332-96f0-fe984663e07f" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc5d57e1-9420-4332-96f0-fe984663e07f")) {                    Plotly.newPlot(                        "cc5d57e1-9420-4332-96f0-fe984663e07f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Таргет\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Таргет","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Таргет","offsetgroup":"Таргет","orientation":"v","showlegend":true,"x":[71.0,72.0,235.0,277.0,109.0,61.0,109.0,78.0,66.0,192.0,52.0,173.0,97.0,216.0,68.0,232.0,237.0,68.0,262.0,116.0,220.0,51.0,131.0,195.0,63.0,144.0,248.0,71.0,52.0,90.0,171.0,77.0,198.0,77.0,167.0,74.0,72.0,201.0,128.0,60.0,257.0,85.0,57.0,151.0,281.0,84.0,80.0,242.0,70.0,53.0,296.0,257.0,161.0,59.0,65.0,217.0,102.0,91.0,261.0,243.0,281.0,144.0,92.0,178.0,270.0,170.0,71.0,179.0,45.0,274.0,182.0,178.0,97.0,58.0,125.0,67.0,116.0,202.0,90.0,281.0,99.0,311.0,259.0,283.0,168.0,191.0,206.0,262.0,155.0,202.0,55.0,202.0,42.0,214.0,173.0,118.0,90.0,129.0,151.0,111.0,53.0,85.0,109.0,200.0,152.0,252.0,155.0,178.0,128.0,258.0,124.0,265.0,189.0,139.0,70.0,302.0,47.0,90.0,200.0,306.0,94.0,31.0,272.0,215.0,137.0,148.0,140.0,99.0,89.0,198.0,242.0,200.0,237.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Предсказание через оптимизацию MSE\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Предсказание через оптимизацию MSE","marker":{"color":"#EF553B","opacity":0.5,"pattern":{"shape":""}},"name":"Предсказание через оптимизацию MSE","offsetgroup":"Предсказание через оптимизацию MSE","orientation":"v","showlegend":true,"x":[138.5021009629515,132.91908985798548,166.67413171383464,199.8429664626785,160.9762982085188,119.0469809226083,167.68143412233314,138.05220937741396,140.06425511003346,185.8796383846826,121.38231924814994,182.26202191079193,149.05163249577996,147.6597917046907,130.50598655516467,171.73998656949735,161.44986774413732,174.71315862900627,163.35080896801296,166.48913467607025,182.83910112965182,110.34440594185477,174.5669582817004,173.43481087969366,129.39772756678516,130.54279007803623,199.35293693261866,121.81289867071104,111.78693747112226,157.5909284709547,175.08245425980138,107.20817357715755,166.69962215493345,120.33213024564083,161.1157616448097,148.42322658911692,129.70702340820168,125.44367750204374,116.07321586727991,129.70630764020714,171.5673001449786,151.59893775975098,109.32808842358565,157.15721020948072,188.98298642982593,153.28285339989404,139.12212838133277,221.14214249268832,111.34618491059683,144.01167823274577,177.15864741447413,175.10662821590444,164.8826522731382,114.91220437970382,113.59000714705397,167.23008644341257,129.84844235406905,166.9743541252919,181.21914680788362,210.25201335898066,194.9837086028278,174.57547175450225,138.11595762878736,138.38676935020996,180.2378378802684,156.54530496914398,120.80393107139832,129.25878972378385,107.78078277722508,186.69473445810516,131.3918159349169,164.8684317975974,142.7650792335983,158.9077324562616,114.48018222160279,142.30432847462018,114.6680964466641,165.48023284229467,107.50405003347716,176.8185818472083,103.97387832094414,171.27128000711127,183.88685739102675,157.31525718904302,167.57213364936572,155.23158758104202,153.72762755282847,167.4947596848236,145.39103121399404,161.33915256722295,110.66603166043299,159.33075872026376,118.14780009732736,135.20728565774778,170.07501491184988,160.19092437975556,119.62547559069745,143.9969667843143,170.19632017905565,165.789706767 ...

# %%
import plotly.express as px
import plotly.graph_objs as go

df = pd.DataFrame(dict(
    series=np.concatenate((["Таргет"] * len(y_test), ["Предсказание через взвешенный MSE"] * len(y_test))),
    data=np.concatenate((y_test, df_test['pred_MSE_weighted']))
))


fig = px.histogram(df, x="data", color="series", barmode="overlay")
fig.update_layout(
                  title="Распределение таргетов и предиктов"
                  , xaxis_title="Таргеты"
                  , yaxis_title="Число"
                  , margin=dict(l=0, r=0, t=50, b=0)
                  , height=600
                  , width=900
                  , font_family="Arial"
                  , font_color="black"
                  , font_size = 20
                  , title_font_family="Times New Roman"
                  , title_font_size = 20
                  , title_font_color="black"
                  , separators=", .*"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3f30cdfd-8709-44df-988e-3e400e8ae855" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f30cdfd-8709-44df-988e-3e400e8ae855")) {                    Plotly.newPlot(                        "3f30cdfd-8709-44df-988e-3e400e8ae855",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Таргет\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Таргет","marker":{"color":"#636efa","opacity":0.5,"pattern":{"shape":""}},"name":"Таргет","offsetgroup":"Таргет","orientation":"v","showlegend":true,"x":[71.0,72.0,235.0,277.0,109.0,61.0,109.0,78.0,66.0,192.0,52.0,173.0,97.0,216.0,68.0,232.0,237.0,68.0,262.0,116.0,220.0,51.0,131.0,195.0,63.0,144.0,248.0,71.0,52.0,90.0,171.0,77.0,198.0,77.0,167.0,74.0,72.0,201.0,128.0,60.0,257.0,85.0,57.0,151.0,281.0,84.0,80.0,242.0,70.0,53.0,296.0,257.0,161.0,59.0,65.0,217.0,102.0,91.0,261.0,243.0,281.0,144.0,92.0,178.0,270.0,170.0,71.0,179.0,45.0,274.0,182.0,178.0,97.0,58.0,125.0,67.0,116.0,202.0,90.0,281.0,99.0,311.0,259.0,283.0,168.0,191.0,206.0,262.0,155.0,202.0,55.0,202.0,42.0,214.0,173.0,118.0,90.0,129.0,151.0,111.0,53.0,85.0,109.0,200.0,152.0,252.0,155.0,178.0,128.0,258.0,124.0,265.0,189.0,139.0,70.0,302.0,47.0,90.0,200.0,306.0,94.0,31.0,272.0,215.0,137.0,148.0,140.0,99.0,89.0,198.0,242.0,200.0,237.0],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"series=Предсказание через взвешенный MSE\u003cbr\u003edata=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Предсказание через взвешенный MSE","marker":{"color":"#EF553B","opacity":0.5,"pattern":{"shape":""}},"name":"Предсказание через взвешенный MSE","offsetgroup":"Предсказание через взвешенный MSE","orientation":"v","showlegend":true,"x":[112.83063607383914,87.16500907090855,169.68538655297442,277.76630041155715,169.11443552963368,82.21778006744313,197.9594418151791,103.83344130209218,111.23579699788678,239.1705404585347,57.52582507963048,231.96874492142769,126.59942328368399,134.49342962272462,98.45131179107831,190.76947240058482,159.04937787045367,196.11703162151073,178.93288702989796,159.61360529076873,199.2756205561916,36.031513059636666,203.4302477463508,212.02155765599207,75.06741778243509,94.93065961005162,257.9769648690246,66.69516789300638,35.67739992378699,164.288610741903,168.88174424894848,31.772559375513865,166.5185028100978,53.41008692341981,183.29923296462115,127.23520381833248,91.14506053407646,85.43894115170767,53.66753989489928,92.19594764992941,185.62164111074688,170.81822051736216,26.162519786359027,154.94478185875096,272.7703714428989,128.26987108591064,85.71701356034941,329.7102929874655,35.500983381272874,117.7376218206467,213.01483193680224,216.30917732876588,186.04946853983836,53.44485825757941,63.389066359219484,170.19237739933902,79.46003688859126,152.52677768676847,236.84656206863227,291.26399380371345,252.11219929524844,187.1576718908312,105.19045549689561,115.1532425856233,222.88317210337067,137.15394677626688,64.84096213023417,89.94716245843205,17.142144974525905,242.0247836787039,104.43797445325262,168.76206531226146,130.96353088685328,158.46749162082608,59.7915695892557,125.75010516954833,34.66150970362702,198.95295012027293,27.75135283811838,236.46909719464458,26.527219644734785,184.28979167289543,229.61998821886314,172.5509200696148,168.87391024439808,172.6466290910701,151.02457450479156,177.14892748290072,141.15550585521382,175.48998176792463,50.928609995181716,148.94504494684764,66.1014791559186,98.65057998976243,196.63810542140533,159.3665790684277,66.59685637776961,140.03553035400805,202.42967026081743,177.3100737925974,92.63794182011827,14 ...

# %% [markdown]
# ## Само задание: попробуйте обучиться сразу на MAPE и измерьте полученный MAPE на всей тестовой выборке

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error as mape

x_full, y_full = load_diabetes(return_X_y=True)
df = pd.DataFrame(x_full)
df['target'] = y_full

test_size = 0.3
random_state = 43
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(['target'], axis=1), df['target'],
    test_size=test_size, random_state=random_state
)

scale_factor = np.mean(y_train)
y_train_scaled = y_train / scale_factor

rng = np.random.default_rng(seed=121)


class sgd_lecture_linear:
    def __init__(self, rng, MAX_ITER=100_000, sample_weights=None,
                 early_stopping=False, validation_fraction=0.1,
                 n_iter_no_change=5000, tol=1e-4):
        self.MAX_ITER = MAX_ITER
        self.w = None
        self.w0 = rng.normal()
        self.loss = None
        self.epsilon = 1e-10
        self.rng = rng
        self.early_stopping = early_stopping
        self.validation_fraction = validation_fraction
        self.n_iter_no_change = n_iter_no_change
        self.tol = tol
        return

    def _f(self, x):
        assert len(x) == len(self.w)
        return np.dot(self.w, x) + self.w0

    def _compute_loss(self, X, y, weights=None):
        predictions = self.predict_proba(X)
        if weights is None:
            weights = np.ones(len(y))
        if self.loss in ['MSE', 'MSE_weighted']:
            return np.mean(weights * (y - predictions) ** 2)
        elif self.loss == 'MAPE':
            abs_errors = np.abs((y - predictions) / (np.abs(y) + self.epsilon))
            return np.mean(weights * abs_errors) * 100

    def _der_loss(self, x, y, weight=1):
        if self.loss in ['MSE', 'MSE_weighted']:
            return -(y - self._f(x)) * x * weight
        elif self.loss == 'MAPE':
            error = y - self._f(x)
            abs_y = np.abs(y) + self.epsilon
            if error >= 0:
                return - (1 / abs_y) * x * weight
            else:
                return (1 / abs_y) * x * weight

    def fit(self, X_train, y_train, loss='MSE', weights=None):
        self.loss = loss
        X_train = np.array(X_train)
        y_train = np.array(y_train)

        if self.early_stopping:
            n_samples = X_train.shape[0]
            n_val = int(n_samples * self.validation_fraction)
            indices = self.rng.permutation(n_samples)
            val_indices = indices[:n_val]
            train_indices = indices[n_val:]

            X_val = X_train[val_indices]
            y_val = y_train[val_indices]
            X_train = X_train[train_indices]
            y_train = y_train[train_indices]

            if weights is not None:
                weights = np.array(weights)
                weights_val = weights[val_indices]
                weights = weights[train_indices]
            else:
                weights_val = None

            best_val_loss = float('inf')
            best_weights = None
            best_w0 = None
            iterations_no_change = 0

        self.w = self.rng.normal(size=X_train.shape[1])
        step = 0.01

        if loss == 'MSE':
            for k in range(self.MAX_ITER):
                rand_index = self.rng.integers(0, X_train.shape[0] - 1)
                x = X_train[rand_index]
                y = y_train[rand_index]
                if k % 20000 == 0 and k != 0:
                    step = step / 2
                self.partial_fit(x, y, step)

                if self.early_stopping and k % 1000 == 0:
                    val_loss = self._compute_loss(X_val, y_val, weights_val)
                    if val_loss < best_val_loss - self.tol:
                        best_val_loss = val_loss
                        best_weights = self.w.copy()
                        best_w0 = self.w0
                        iterations_no_change = 0
                    else:
                        iterations_no_change += 1000
                    if iterations_no_change >= self.n_iter_no_change:
                        self.w = best_weights
                        self.w0 = best_w0
                        break

        elif loss in ['MSE_weighted', 'MAPE']:
            for k in range(self.MAX_ITER):
                rand_index = self.rng.integers(0, X_train.shape[0] - 1)
                x = X_train[rand_index]
                y = y_train[rand_index]
                weight = np.array(weights)[rand_index] if weights is not None else 1
                if k % 20000 == 0 and k != 0:
                    step = step / 2
                self.partial_fit(x, y, step, weight=weight)

                if self.early_stopping and k % 1000 == 0:
                    val_loss = self._compute_loss(X_val, y_val, weights_val)
                    if val_loss < best_val_loss - self.tol:
                        best_val_loss = val_loss
                        best_weights = self.w.copy()
                        best_w0 = self.w0
                        iterations_no_change = 0
                    else:
                        iterations_no_change += 1000
                    if iterations_no_change >= self.n_iter_no_change:
                        self.w = best_weights
                        self.w0 = best_w0
                        break

    def partial_fit(self, x, y, step=0.01, weight=1):
        if self.w is None:
            self.w = self.rng.normal(size=len(x))
        dl = self._der_loss(x, y, weight=weight)
        self.w -= step * dl
        if self.loss == 'MSE':
            self.w0 -= - step * (y - self._f(x))
        elif self.loss == 'MSE_weighted':
            self.w0 -= - step * (y - self._f(x)) * weight
        elif self.loss == 'MAPE':
            error = y - self._f(x)
            abs_y = np.abs(y) + self.epsilon
            if error >= 0:
                grad_w0 = - (1 / abs_y) * weight
            else:
                grad_w0 = (1 / abs_y) * weight
            self.w0 -= step * grad_w0

    def predict_proba(self, X):
        X = np.array(X)
        if X.ndim == 1:
            return self._f(X)
        return X @ self.w + self.w0


sgd_mape = sgd_lecture_linear(rng, MAX_ITER=100_000, early_stopping=True)
weights = np.ones(len(y_train_scaled))
sgd_mape.fit(x_train, y_train_scaled, loss='MAPE', weights=weights)
pred_scaled = sgd_mape.predict_proba(x_test)
pred = np.array(pred_scaled) * scale_factor
mape_value = mape(y_test, pred)
print(f'{mape_value:.2f}', ' -- MAPE на тесте при обучении на MAPE')
# Out:
# 0.34  -- MAPE на тесте при обучении на MAPE

# %% [markdown]
# Вопрос: в какой интервал попадает MAPE на тесте при обучении на MAPE?
#
#
#
# 1.   0.34 -- 0.37 <-----
# 2.   0.37 -- 0.40
# 3.   0.41 -- 0.43
# 4.   0.44 -- 0.47
